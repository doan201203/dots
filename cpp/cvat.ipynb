# %%
import datumaro as dm
import numpy as np
data_dir = '/home/trdoan20/miniproject/SegmentationClass/1020_IMG_20180928_225945.png'
# dataset = dm.Dataset.import_from(data_dir, 'cvat')
mask = dm.util.mask_tools.load_mask(data_dir)
cl = np.unique(mask[:, :, 0])
print(cl)
from matplotlib import pyplot as plt
plt.imshow(mask)
# Out:
# [  0 102 240 255]
